# %%
# Импорт из core
from core.config import get_config
from core.system_context.system_context import SystemContext
from core.session_context.session_context import SessionContext
# 1. Загрузка конфигурации
config = get_config(profile='dev')
# 2. Создание системного контекста
system_context = SystemContext(config)
# 3. Инициализация системного контекста
success = await system_context.initialize()
# Out:
# INFO:core.system_context.system_context:SystemContext создан (ID: af4188b5-0c2e-4e0c-82af-f5dc00460d50)
# INFO:core.system_context.system_context:Инициализация системы (ID: af4188b5-0c2e-4e0c-82af-f5dc00460d50) с профилем: dev
# INFO:core.infrastructure.providers.llm.base_llm:Создан LLM-провайдер для модели: tngtech/deepseek-r1t2-chimera:free
# INFO:core.infrastructure.providers.llm.openrouter_provider:OpenRouter request completed. Model: tngtech/deepseek-r1t2-chimera:free, Tokens used: 145, Time: 5.79s
# INFO:core.infrastructure.providers.llm.openrouter_provider:OpenRouterProvider успешно инициализирован. Модель: tngtech/deepseek-r1t2-chimera:free
# INFO:core.system_context.factory:LLM провайдер 'default_llm' (openrouter) успешно создан и инициализирован
# INFO:core.system_context.system_context:LLM провайдер 'default_llm' успешно зарегистрирован
# INFO:core.infrastructure.providers.database.base_db:Создан DB провайдер для базы: postgres@localhost
# INFO:core.infrastructure.providers.database.postgres_provider:Инициализация PostgreSQL провайдера для базы: postgres
# INFO:core.infrastructure.providers.database.postgres_provider:Создание пула соединений с PostgreSQL: localhost:5432/postgres
# INFO:core.infrastructure.providers.database.postgres_provider:Подключено к PostgreSQL: PostgreSQL 13.22, compiled by Visual C++ build 1925, 64-bit
# INFO:core.infrastructure.providers.database.postgres_provider:PostgreSQL провайдер успешно инициализирован за 0.09 секунд
# INFO:core.system_context.factory:DB провайдер 'default_db' (postgres) успешно создан и инициализирован
# INFO:core.system_context.system_context:DB провайдер 'default_db' успешно зарегистрирован
# INFO:core.system_context.factory:Сканирование директории инструментов: core\infrastructure\tools
# DEBUG:core.system_context.factory:Найден класс инструмента 'ast_parser'
# DEBUG:core.system_context.factory:Найден класс инструмента 'file_lister'
# DEBUG:core.system_context.factory:Найден класс инструмента 'file_reader'
# DEBUG:core.system_context.factory:Найден класс инструмента 'file_writer'
# DEBUG:core.system_context.factory:Найден класс инструмента 'sql_tool'
# INFO:core.system_context.factory:Найдено классов инструментов: 5
# DEBUG:core.system_context.factory:Создание инструмента 'ast_parser' из класса ASTParserTool
# ERROR:core.infrastructure.tools.ast_parser_tool:Не удалось получить инструмент file_reader
# INFO:core.system_context.factory:Инструмент 'ast_parser' успешно создан
# DEBUG:core.system_context.factory:Создание инструмента 'file_lister' из класса FileListerTool
# INFO:core.system_context.factory:Инструмент 'file_lister' успешно создан
# DEBUG:core.system_context.factory:Создание инструмента 'file_reader' из класса FileReaderTool
# INFO:core.system_context.factory:Инструмент 'file_reader' успешно создан
# DEBUG:core.system_context.factory:Создание инструмента 'file_writer' из класса FileWriterTool
# INFO:core.system_context.factory:Инструмент 'file_writer' успешно создан
# DEBUG:core.system_context.factory:Создание инструмента 'sql_tool' из класса SQLTool
# INFO:core.system_context.factory:Инструмент 'sql_tool' успешно создан
# INFO:core.system_context.factory:Инструмент 'ast_parser' успешно зарегистрирован в реестре
# INFO:core.system_context.factory:Инструмент 'file_lister' успешно зарегистрирован в реестре
# INFO:core.system_context.factory:Инструмент 'file_reader' успешно зарегистрирован в реестре
# INFO:core.system_context.factory:Инструмент 'file_writer' успешно зарегистрирован в реестре
# INFO:core.system_context.factory:Инструмент 'sql_tool' успешно зарегистрирован в реестре
# INFO:core.system_context.factory:Успешно создано и зарегистрировано инструментов: 5
# INFO:core.system_context.factory:Сканирование директории навыков: core\skills
# DEBUG:core.system_context.factory:Найден класс навыка 'planning'
# DEBUG:core.system_context.factory:Найден класс навыка 'project_map'
# DEBUG:core.system_context.factory:Найден класс навыка 'project_navigator'
# DEBUG:core.system_context.factory:Найден класс навыка 'table_description'
# INFO:core.system_context.factory:Найдено классов навыков: 4
# DEBUG:core.system_context.factory:Создание навыка 'planning' из класса PlanningSkill
# INFO:core.skills.planning.skill:Инициализирован навык планирования: planning
# INFO:core.system_context.factory:Навык 'planning' успешно создан
# DEBUG:core.system_context.factory:Создание навыка 'project_map' из класса ProjectMapSkill
# INFO:core.skills.project_map.skill:Инициализирован навык карты проекта: project_map
# INFO:core.skills.project_map.skill:ProjectMapSkill успешно инициализирован
# INFO:core.system_context.factory:Навык 'project_map' успешно создан
# DEBUG:core.system_context.factory:Создание навыка 'project_navigator' из класса ProjectNavigatorSkill
# INFO:core.skills.project_navigator.skill:Инициализирован навык навигации: project_navigator
# ERROR:core.skills.project_navigator.skill:Не найден сервис 'ast_processing' в системном контексте
# INFO:core.system_context.factory:Навык 'project_navigator' успешно создан
# DEBUG:core.system_context.factory:Создание навыка 'table_description' из класса TableDescriptionSkill
# INFO:asyncio:Инициализирован навык получения описания: table_description
# INFO:core.system_context.factory:Навык 'table_description' успешно создан
# INFO:core.system_context.factory:Навык 'planning' успешно зарегистрирован в реестре
# INFO:core.system_context.factory:Навык 'project_map' успешно зарегистрирован в реестре
# INFO:core.system_context.factory:Навык 'project_navigator' успешно зарегистрирован в реестре
# INFO:core.system_context.factory:Навык 'table_description' успешно зарегистрирован в реестре
# INFO:core.system_context.factory:Успешно создано и зарегистрировано навыков: 4
# INFO:core.infrastructure.services.code_analysis.language_registry:Зарегистрирован адаптер языка: python (py, pyi, pyw)
# INFO:core.system_context.factory:Базовые сервисы (language_registry) зарегистрированы
# INFO:core.system_context.factory:Сканирование директории сервисов: core\infrastructure\services
# DEBUG:core.system_context.factory:Найден класс сервиса 'ASTProcessingService' -> зарегистрирован как 'ast_processing'
# INFO:core.system_context.factory:Найдено классов сервисов: 1
# DEBUG:core.system_context.factory:Создание экземпляра сервиса 'ast_processing' из класса ASTProcessingService
# DEBUG:core.system_context.factory:Экземпляр сервиса 'ast_processing' создан
# INFO:core.system_context.factory:Сервис 'ast_processing' зарегистрирован в реестре
# INFO:core.system_context.lifecycle_manager:Начало инициализации системы...
# INFO:core.infrastructure.services.code_analysis.adapters.python_adapter:PythonLanguageAdapter успешно инициализирован с поддержкой всех конструкций Python 3.x

# %%
agent = await system_context.create_agent()

# %%
# 3. Выполнение агента
result = await agent.run("Проанализируй структуру текущего проекта и опиши основные компоненты.")

# %%
tool = system_context.get_resource("code_navigation")

# %%
tool

# %%
pwd

# %%
from core.infrastructure.tools.file_lister_tool import FileListerInput
tool = system_context.get_resource("file_lister")
result = await tool.execute(FileListerInput(
        path= ".",  # текущая директория
        recursive= True,
        max_items= 1000,
        include_files= True,
        include_directories= True,
        extensions = ['py']
))

# %%
# Пример результатов
items = result.items
py_files = [item for item in items if item.type == "file" and item.name.endswith(".py")]
print(f"Найдено .py файлов: {len(py_files)}")

# %%
py_files

# %%
len(result.items)

# %%
result

# %%
from core.infrastructure.tools.ast_parser_tool import ASTParserInput
tool = system_context.get_resource("ASTParserTool")
result = await tool.execute(ASTParserInput(file_path='core\\agent_runtime\\executor.py'))

# %%
print(result.source_code)

# %%
result

# %%
from tree_sitter import Tree
from tree_sitter import Language, Parser
import tree_sitter_python

# 1. Инициализация парсера (например, для Python)
PY_LANGUAGE = Language(tree_sitter_python.language())
parser = Parser(language = PY_LANGUAGE)

# 2. Исходный код
source_code = b"def hello(): print('world')"

# 3. Парсинг
tree = parser.parse(source_code)
root_node = tree.root_node

# --- Альтернатива: рекурсивная печать ---
def print_tree(node, indent=0):
    print(' ' * indent + f"{node.type} [{node.start_point} - {node.end_point}]")
    for child in node.children:
        print_tree(child, indent + 2)

print_tree(root_node)

# %%
# Выполнение SQL-запроса
sql_result = await system_context.execute_sql_query(
    query='SELECT * FROM "Lib".authors a where a.last_name  = $1 and first_name =$2',
    params={"author": "Толстой", "first_name": "Лев"}
)

# %%
sql_result

# %%
from core.session_context.session_context import SessionContext
session = SessionContext()
session.set_goal("Какие книги написал Пушкин?")

# %%
# Запуск конкретного навыка
skill_result = await system_context.run_capability(
    capability_name="table_description.get_description",
    parameters={"schema_name":"Lib", "table_name":"book_genres", "format": "json",
    "include_examples":True, "max_examples":3},
    session_context=session)

# %%
skill_result.result

# %%
system_context.get_capability('table_description.get_description')

# %%
session.__dict__

# %%
session.step_context.__dict__

# %%
system_context.config.agent["default"].get("max_steps", 10)

# %%
system_context.config.agent.get("max_steps", 10)

# %%
# Выполнение запроса к LLM
llm_response = await system_context.call_llm_with_params(
    user_prompt="Какие преимущества у искусственного интеллекта?",
    system_prompt="Ты — эксперт по ИИ. Отвечай развернуто и по делу.",
    temperature=0.7,
    max_tokens=300
)

# %%
llm_response

# %%
from core.session_context.session_context import SessionContext
session = SessionContext()
session.set_goal("Какие книги написал Пушкин?")

# %%
# Запуск конкретного навыка
skill_result = await system_context.run_skill(
    skill_name="PlanningSkill",
    capability_name="planning.create_plan",
    parameters={},
    session_context=session)

# %%
session.__dict__

# %%
session.data_context.__dict__

# %%
skill_result

# %%
system_context.registry.__dict__

# %%
system_context.get_resource("PlanningSkill").__dict__

# %%
# !pip install -U tree-sitter

# %%
# !pip install tree-sitter-kotlin

# %%
# !pip list
